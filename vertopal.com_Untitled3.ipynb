# %% [markdown]
# > Untitled3
# > April 18, 2023
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>a Vehicle <strong>class in</strong> Python <strong>with</strong> an
# _init_ method that initializes instance␣ ↪variables name_of_vehicle,
# max_speed,</p>
# <p><strong>class Vehicle</strong>:<br />
# <strong>def</strong> _init_(self, name_of_vehicle, max_speed,
# average_of_vehicle): self.name_of_vehicle = name_of_vehicle<br />
# self.max_speed = max_speed<br />
# self.average_of_vehicle = average_of_vehicle<br />
# In this example, the Vehicle <strong>class has</strong> an _init_ method
# that takes three␣</p>
# <p><strong>and</strong> average_of_vehicle. These arguments are used to
# initialize the instance␣↪arguments: name_of_vehicle, max_speed,<br />
# ↪variables of the <strong>class using</strong> the self keyword.</p>
# <p>The name_of_vehicle instance variable stores the name of the vehicle,
# the␣</p>
# <p>speed of the vehicle, <strong>and</strong> the average_of_vehicle
# instance variable stores the␣↪max_speed instance variable stores the
# maximum<br />
# ↪average of the vehicle.</p>
# <p>We can create an object of the Vehicle <strong>class and</strong>
# initialize its instance␣ ↪variables like this:<br />
# car = Vehicle("Car", 200, 10)<br />
# In this example, we create an object car of the Vehicle <strong>class
# and pass in</strong> the␣</p>
# <p>max_speed <strong>as</strong> 200, <strong>and</strong>
# average_of_vehicle <strong>as</strong> 10. The _init_ method
# initializes␣↪values <strong>for</strong> name_of_vehicle
# <strong>as</strong> "Car",<br />
# ↪the instance variables of the car object</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[ \]: 1.
#
# > We can access the instance variables of the car object like this:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print("Name of vehicle:", car.name_of_vehicle)<br />
# print("Max speed:", car.max_speed)<br />
# print("Average of vehicle:", car.average_of_vehicle) This will
# output:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 1
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Name of vehicle: Car<br />
# Max speed: 200<br />
# Average of vehicle: 10</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><p>[ ]: 2.</p>
# <blockquote>
# <p>Here's an example of a child class Car that inherits from the Vehicle
# class and␣ ↪has a method named seating_capacity:<br />
# <strong>class Car</strong>(Vehicle):<br />
# <strong>def</strong> seating_capacity(self, capacity):<br />
# <strong>return</strong>
# f"<strong>{</strong>self.name_of_vehicle<strong>}</strong> has a seating
# capacity of <strong>{</strong>capacity<strong>}</strong>␣</p>
# <p>In this example, the Car <strong>class is</strong> defined
# <strong>as</strong> a subclass of the Vehicle
# <strong>class</strong>␣↪people."</p>
# <p>This means that the Car <strong>class inherits</strong> all the
# instance variables <strong>and</strong> methods␣↪<strong>using</strong>
# the parentheses after the <strong>class name</strong>.</p>
# <p>↪of the Vehicle class.</p>
# </blockquote>
# <p>The seating_capacity method takes an argument capacity which
# represents the␣</p>
# <blockquote>
# <p>This method returns a string that includes the name of the car
# <strong>and</strong> its seating␣↪seating capacity of the car.</p>
# <p>↪capacity.</p>
# <p>We can create an object of the Car <strong>class and</strong> call
# its seating_capacity method␣ ↪like this:<br />
# car = Car("Sedan", 180, 8)<br />
# print(car.seating_capacity(5))</p>
# <p>In this example, we create an object car of the Car <strong>class and
# pass in</strong> the␣</p>
# <p>max_speed <strong>as</strong> 180, <strong>and</strong>
# average_of_vehicle <strong>as</strong> 8. We then call the␣↪values
# <strong>for</strong> name_of_vehicle <strong>as</strong> "Sedan",</p>
# <p><strong>in</strong> the value 5 <strong>as</strong> the capacity
# argument. The method returns a string that␣↪seating_capacity method of
# the car object <strong>and pass</strong><br />
# ↪includes the name of the car <strong>and</strong> its seating</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>This will output:<br />
# Sedan has a seating capacity of 5 people.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><p>[ ]: 3.</p>
# <p>Multiple inheritance <strong>is</strong> a feature
# <strong>in</strong> object-oriented programming <strong>in</strong>
# which a␣</p>
# <blockquote>
# <p><strong>from multiple</strong> parent classes. Here's a simple
# example code demonstrating␣↪<strong>class can</strong> inherit
# attributes <strong>and</strong> methods</p>
# <p><strong>class A</strong>:↪multiple inheritance in Python:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# 2
#
# > **def** method_a(self):
# > print("Method A")
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class B</strong>:<br />
# <strong>def</strong> method_b(self):<br />
# print("Method B")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class C</strong>(A, B):<br />
# <strong>def</strong> method_c(self):<br />
# print("Method C")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>c = C()<br />
# c.method_a()<br />
# outputs "Method A"<br />
# c.method_b()<br />
# outputs "Method B"<br />
# c.method_c()<br />
# outputs "Method C"</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In this example, we have three classes: A, B, <strong>and</strong> C.
# A <strong>and</strong> B are parent classes␣ ↪of C, which means that C
# inherits attributes</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>The A <strong>class has</strong> a method named method_a that prints
# out a message indicating␣ ↪that Method A has been called.</p>
# <p>The B <strong>class has</strong> a method named method_b that prints
# out a message indicating␣ ↪that Method B has been called.</p>
# <p>The C <strong>class is</strong> a subclass of both A
# <strong>and</strong> B. It has a method named method_c that␣ ↪prints out
# a message indicating that Method C</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>We create an object c of the C <strong>class and</strong> call its
# methods. We can see that c <strong>is</strong>␣ ↪able to inherit
# attributes <strong>and</strong> methods <strong>from</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Output:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Method A<br />
# Method B<br />
# Method C</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In Python, getters <strong>and</strong> setters are methods that
# allow us to retrieve <strong>and</strong> modify␣</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# ↪the values of private attributes of a class, \[ \]: 4.
#
# 3
#
# > respectively.
# >
# > Here's an example of a class with a getter and a setter method in
# > Python:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Student</strong>:<br />
# <strong>def</strong> _init_(self, name, age):<br />
# self._name = name<br />
# self._age = age</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **def** get_name(self):
# > **return** self.\_name
# >
# > **def** set_name(self, name):
# > self.\_name = name
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> get_age(self):<br />
# <strong>return</strong> self._age</p>
# <p><strong>def</strong> set_age(self, age):<br />
# self._age = age<br />
# In this example, we have a Student <strong>class with</strong> private
# attributes name <strong>and</strong> _age.␣</p>
# <p><strong>for</strong> both attributes using the naming convention of
# get&lt;attribute_name&gt; <strong>and</strong>␣↪We have defined getter
# <strong>and</strong> setter methods<br />
# ↪set_&lt;attribute_name&gt;.</p>
# <p>The getter methods get_name <strong>and</strong> get_age
# <strong>return</strong> the values of the _name <strong>and</strong>
# _age␣ ↪attributes, respectively.</p>
# <p>The setter methods set_name <strong>and</strong> set_age allow us to
# modify the values of the␣ ↪_name <strong>and</strong> _age attributes,
# respectively.</p>
# <p>We can use these methods to get <strong>and</strong> set the values
# of the private attributes of␣ ↪a Student object, like so:<br />
# student = Student("Alice", 20)<br />
# print(student.get_name())<br />
# outputs "Alice"<br />
# student.set_name("Bob")<br />
# print(student.get_name())<br />
# outputs "Bob"<br />
# print(student.get_age())<br />
# outputs 20<br />
# student.set_age(21)<br />
# print(student.get_age())<br />
# outputs 21</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Output:
#
# 4
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Alice<br />
# Bob<br />
# 20<br />
# 21</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Method overriding <strong>is</strong> a concept <strong>in</strong>
# object-oriented programming where a subclass␣ ↪provides its own
# implementation of a method</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[ \]: 5.
#
# > Here's an example code demonstrating method overriding in Python:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Animal</strong>:<br />
# <strong>def</strong> sound(self):<br />
# print("Animal is making a sound")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Dog</strong>(Animal):<br />
# <strong>def</strong> sound(self):<br />
# print("Dog is barking")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Cat</strong>(Animal):<br />
# <strong>def</strong> sound(self):<br />
# print("Cat is meowing")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>animal = Animal()<br />
# animal.sound()<br />
# outputs "Animal is making a sound"</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>dog = Dog()<br />
# dog.sound()<br />
# outputs "Dog is barking"</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>cat = Cat()<br />
# cat.sound()<br />
# outputs "Cat is meowing"<br />
# In this example, we have a parent <strong>class Animal with</strong> a
# method sound that prints␣ ↪a generic message.</p>
# <p>The Dog <strong>and</strong> Cat classes are subclasses of Animal
# <strong>and</strong> they both override the␣ ↪sound method
# <strong>with</strong> their own implementation</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>We create objects of Animal, Dog, <strong>and</strong> Cat classes
# <strong>and</strong> call the sound method on␣ ↪each of them. We can see
# that the subclass</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Output:
#
# 5
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Animal <strong>is</strong> making a sound<br />
# Dog <strong>is</strong> barking<br />
# Cat <strong>is</strong> meowing</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 6
